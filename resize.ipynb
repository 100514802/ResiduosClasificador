# %%
import os
import constants
import numpy as np
from scipy import misc, ndimage
import imageio
from PIL import Image  # Usaremos PIL (Pillow) para redimensionar las imágenes

def resize(image, dim1, dim2):
    pil_image = Image.fromarray(image)
    pil_image_resized = pil_image.resize((dim1, dim2))
    return np.array(pil_image_resized)

def fileWalk(directory, destPath):
    try:
        os.makedirs(destPath)
    except OSError:
        if not os.path.isdir(destPath):
            raise

    for subdir, dirs, files in os.walk(directory):
        for file in files:
            if len(file) <= 4 or file[-4:] != '.jpg':
                continue

            pic = imageio.imread(os.path.join(subdir, file))
            dim1, dim2, _ = pic.shape  # Obtener las dimensiones de la imagen

            if dim1 > dim2:
                pic = np.rot90(pic)

            picResized = resize(pic, constants.DIM1, constants.DIM2)
            imageio.imwrite(os.path.join(destPath, file), picResized)

def main():
    prepath = os.path.join(os.getcwd(), 'dataset-original')
    glassDir = os.path.join(prepath, 'glass')
    paperDir = os.path.join(prepath, 'paper')
    cardboardDir = os.path.join(prepath, 'cardboard')
    plasticDir = os.path.join(prepath, 'plastic')
    metalDir = os.path.join(prepath, 'metal')
    trashDir = os.path.join(prepath, 'trash')

    destPath = os.path.join(os.getcwd(), 'dataset-resized2')
    try:
        os.makedirs(destPath)
    except OSError:
        if not os.path.isdir(destPath):
            raise

    # GLASS
    fileWalk(glassDir, os.path.join(destPath, 'glass'))

    # PAPER
    fileWalk(paperDir, os.path.join(destPath, 'paper'))

    # CARDBOARD
    fileWalk(cardboardDir, os.path.join(destPath, 'cardboard'))

    # PLASTIC
    fileWalk(plasticDir, os.path.join(destPath, 'plastic'))

    # METAL
    fileWalk(metalDir, os.path.join(destPath, 'metal'))

    # TRASH
    fileWalk(trashDir, os.path.join(destPath, 'trash'))

if __name__ == '__main__':
    main()


#
#def resize(image, dim1, dim2):
#	return misc.imresize(image, (dim1, dim2))
#
#def fileWalk(directory, destPath):
#	try: 
#		os.makedirs(destPath)
#	except OSError:
#		if not os.path.isdir(destPath):
#			raise
#
#	for subdir, dirs, files in os.walk(directory):
#		for file in files:
#			if len(file) <= 4 or file[-4:] != '.jpg':
#				continue
#
#			pic = misc.imread(os.path.join(subdir, file))
#			dim1 = len(pic)
#			dim2 = len(pic[0])
#			if dim1 > dim2:
#				pic = np.rot90(pic)
#
#			picResized = resize(pic,constants.DIM1, constants.DIM2)
#			misc.imsave(os.path.join(destPath, file), picResized)
#		
#
#def main():
#	prepath = os.path.join(os.getcwd(), 'dataset-original')
#	glassDir = os.path.join(prepath, 'glass')
#	paperDir = os.path.join(prepath, 'paper')
#	cardboardDir = os.path.join(prepath, 'cardboard')
#	plasticDir = os.path.join(prepath, 'plastic')
#	metalDir = os.path.join(prepath, 'metal')
#	trashDir = os.path.join(prepath, 'trash')
#
#	destPath = os.path.join(os.getcwd(), 'dataset-resized2')
#	try: 
#		os.makedirs(destPath)
#	except OSError:
#		if not os.path.isdir(destPath):
#			raise
#
#	#GLASS
#	fileWalk(glassDir, os.path.join(destPath, 'glass'))
#
#	#PAPER
#	fileWalk(paperDir, os.path.join(destPath, 'paper'))
#
#	#CARDBOARD
#	fileWalk(cardboardDir, os.path.join(destPath, 'cardboard'))
#
#	#PLASTIC
#	fileWalk(plasticDir, os.path.join(destPath, 'plastic'))
#
#	#METAL
#	fileWalk(metalDir, os.path.join(destPath, 'metal'))
#
#	#TRASH
#	fileWalk(trashDir, os.path.join(destPath, 'trash'))  
#
#if __name__ == '__main__':
#    main()
# Out:
# C:\Users\quiqu\AppData\Local\Temp\ipykernel_12328\1782638607.py:25: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   pic = imageio.imread(os.path.join(subdir, file))
